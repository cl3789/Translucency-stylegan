# %%
import pandas as pd
import numpy as np
import os
import fnmatch, re

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn import preprocessing

import matplotlib

import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats
from scipy.stats import pearsonr, kendalltau, spearmanr

# %%
def drop_demos(data,data_type,num_row_to_drop):
    data = data.drop(range(0,num_row_to_drop))
    if data_type == "real-fake-judgement":
        data['ground_truth'] = data['ground_truth'].astype(int)
        data = data.replace([0,1],["fake", "real"])
    elif data_type == "SAR":
        data["ground_truth"] = data["ground_truth"].replace(["0","1"],["fake", "real"])
    return data

def process_individual_SAR(file_path, file_name, column_to_read, rows_to_skip):
    participant_file_path = os.path.join(file_path, file_name)
    participant_data = pd.read_csv(participant_file_path, usecols = column_to_read)
    
    participant_data = drop_demos(participant_data, "SAR", rows_to_skip)
    return participant_data

def process_all_people_SAR(file_path, attribute_name):
    files = list(filter(lambda f: os.path.isfile(os.path.join(file_path,f)), os.listdir(file_path)))

    df_stat = pd.DataFrame()
    
    trial_num_path = os.path.join(file_path, files[0])
    print(trial_num_path)
    
    image_info = ["Trial_num","image_name", "image_path","ground_truth"]
    aggregate = pd.read_csv(trial_num_path, usecols = image_info)
    aggregate = drop_demos(aggregate, "SAR", 5)
    
    use_response = ["Trial_num","image_name","image_path", "ground_truth", attribute_name]
    
    for person_data in files:
        if fnmatch.fnmatch(person_data, '*.csv'):
            person_result = process_individual_SAR(file_path, person_data, use_response, 5)
            #Normalize to 0-1 range
            person_result[attribute_name] = (person_result[attribute_name]-person_result[attribute_name].min())/(person_result[attribute_name].max()-person_result[attribute_name].min())
            aggregate = pd.concat([aggregate, person_result[attribute_name]], axis=1)
            all_res_name = attribute_name + "_all"
            aggregate[all_res_name] =  aggregate[aggregate.columns[4]].values.tolist()
            aggregate["mean_rating"] = aggregate[all_res_name].apply(np.mean)
            
    return aggregate

# %%
## Read the data
SAR_folder_path = "data/semantic-rating-good-data"

seethroughness_score = process_all_people_SAR(SAR_folder_path, "seethroughness_score.response")
translucency_score = process_all_people_SAR(SAR_folder_path, "translucency_score.response")
glow_score = process_all_people_SAR(SAR_folder_path, "glow_score.response")
# Out:
# data/semantic-rating-good-data/Rory Hayes_SAR-soap_2022_Mar_24_1356.csv
# data/semantic-rating-good-data/Rory Hayes_SAR-soap_2022_Mar_24_1356.csv
# data/semantic-rating-good-data/Rory Hayes_SAR-soap_2022_Mar_24_1356.csv

# %%
len(list(glow_score["glow_score.response_all"])[0])
# Out:
# 20

# %% [markdown]
# # Define plot functions and color palette

# %%
real_fake_color_palette = dict(real="#9b59b6", fake="#95a5a6")
#real_fake_color_palette = dict(real="#1f85be", fake="#f56c3f")

real_fake_hue_order = ["real","fake"]

# %%
def plot_violin_swarm(df, title):
    plot = sns.violinplot(x="ground_truth", y="mean_rating", data=df, 
                                 hue_order=real_fake_hue_order, scale="count", split=False,
                                 palette=real_fake_color_palette, cut = 0)
#     plot = sns.swarmplot(x="ground_truth", y="mean_rating", data=df, hue_order=["real","fake"], size=2.5,
#                        color="black", edgecolor="gray")
    plot.set(xlabel='Ground truth ', ylabel='Normalized attribute rating', ylim=(0, 1),
                           title='Distribution of mean ratings | ' + title )

# %%
def plot_hist(df, title):
#     plot = sns.histplot(data=df, x="mean_rating", hue="ground_truth",binwidth = 0.2,stat="percent", alpha=0.3,
#                                  hue_order=real_fake_hue_order,
#                                  multiple="dodge", shrink=1,
#                                  palette=real_fake_color_palette)
#     plot = sns.swarmplot(x="ground_truth", y="mean_rating", data=df, hue_order=["real","fake"], size=2.5,
#                        color="black", edgecolor="gray")
    #plot.set(xlabel='Ground truth ', ylabel='Normalized attribute rating', ylim=(0,30),
    #                       title='Distribution of mean ratings | ' + title )
#     fig, ax = plt.subplots()
#     # the size of A4 paper
#     fig.set_size_inches(10, 5)
    plot = sns.histplot(data=df, x="mean_rating", hue="ground_truth",binwidth = 0.2,stat="percent", alpha=0.3,
                                 hue_order=real_fake_hue_order,
                                 shrink=1,common_norm=False,
                                 palette=real_fake_color_palette)
    
    
#     plot = sns.FacetGrid(df, col="ground_truth", margin_titles=False, hue = "ground_truth",
#                      palette=real_fake_color_palette,
#                         height=3.5, aspect=1)
#     plot.map(sns.histplot, "mean_rating", binwidth = 0.2,stat="percent", alpha=0.6)
    plot.set(xticks=np.arange(0,1.2,0.2), yticks=np.arange(0,61,20))
#     plot.set_titles(row_template = ' ', col_template = ' ')

    sns.move_legend(plot, "upper left", bbox_to_anchor=(1, 1), title='Groun truth')
    sns.set_context(context='poster', font_scale=0.8)
    sns.despine()

# %%
plot_hist(translucency_score, "Trans")

# %%
#plot_violin_swarm(seethroughness_score, "See-throughness")
plot_hist(seethroughness_score, "See-throughness")

# %%
#plot_violin_swarm(glow_score, "Glow")
plot_hist(glow_score, "Glow")

# %% [markdown]
# # Merge All Attribute Mean ratings

# %%
def combine_attributes():
    all_attribute_wide = pd.DataFrame({'image_name':translucency_score['image_name'],
                                    'image_path':translucency_score['image_path'],
                                  'ground_truth':translucency_score['ground_truth'],
                                  'translucency_mean':translucency_score["mean_rating"],
                                  'see_throughness_mean':seethroughness_score["mean_rating"],
                                  'glow_mean':glow_score["mean_rating"]}) 

    all_attribute_long = pd.melt(all_attribute_wide, id_vars=['image_name','image_path','ground_truth'],
                            var_name='attribute', value_name='mean_rating',
            value_vars=['translucency_mean', 'see_throughness_mean','glow_mean'])
    
    return all_attribute_wide, all_attribute_long

all_attributes_wide, all_attribute_long = combine_attributes()

# %%
all_attributes_wide[all_attributes_wide["ground_truth"] == "fake"].sort_values(by=['translucency_mean'])
# Out:
#                       image_name  \
# 302  encoded_Group2_IMG_0545.jpg
# 200  encoded_Group2_IMG_9681.jpg
# 139  encoded_Group2_IMG_0139.jpg
# 34   encoded_Group2_IMG_1025.jpg
# 115  encoded_Group2_IMG_5433.jpg
# ..                           ...
# 155  encoded_Group2_IMG_0155.jpg
# 165  encoded_Group2_IMG_9736.jpg
# 66   encoded_Group2_IMG_9726.jpg
# 212  encoded_Group2_IMG_0441.jpg
# 32   encoded_Group2_IMG_0434.jpg
#
#                                             image_path ground_truth  \
# 302  Group1-stimuli/group1-block2/fake-group2-b2/en...         fake
# 200  Group1-stimuli/group1-block2/fake-group2-b2/en...         fake
# 139  Group1-stimuli/group1-block1/fake-group2-b1/en...         fake
# 34   Group1-stimuli/group1-block1/fake-group2-b1/en...         fake
# 115  Group1-stimuli/group1-block1/fake-group2-b1/en...         fake
# ..                                                 ...          ...
# 155  Group1-stimuli/group1-block2/fake-group2-b2/en...         fake
# ...

# %%
all_attributes_wide.to_csv("human_rating.csv")

# %%
all_attribute_long

# %% [markdown]
# # Violin plot

# %%
plot_mean_attribute = sns.violinplot(data=all_attribute_long, x='attribute', y='mean_rating',
                                     split=False, hue="ground_truth", cut=0,
                                     palette=real_fake_color_palette,
                                     scale="count", inner="quartile")
plot_mean_attribute.set(xlabel='Attribute', ylabel='Mean attribute rating')
                           #title='Distribution of mean ratings')
sns.move_legend(plot_mean_attribute, "upper left", bbox_to_anchor=(1, 1), title='Groun truth')

# %% [markdown]
# # Pair plot

# %%
def corrfunc(x, y, **kws):
    r, p = stats.spearmanr(x, y)
    ax = plt.gca()
    # count how many annotations are already present
    n = len([c for c in ax.get_children() if 
                  isinstance(c, matplotlib.text.Annotation)])
    #pos = (.1, .9 - .1*n)
    # or make positions for every label by hand
    pos = (.1, .9) if kws['label'] == 'real' else (.1,.85)

    ax.annotate("{}: rho = {:.3f}".format(kws['label'],r),fontsize = 20,
                xy=pos, xycoords=ax.transAxes)
    
def my_hist(x, label, color):
    ax0 = plt.gca()
    ax = ax0.twinx()
    
    sns.despine(ax=ax, left=True, top=True, right=False)
    ax.yaxis.tick_right()
    ax.set_ylabel('Counts')
    
    ax.hist(x, label=label, color=color)

# %%
stats.spearmanr(all_attributes_wide[all_attributes_wide["ground_truth"]=="fake"]["translucency_mean"], 
                all_attributes_wide[all_attributes_wide["ground_truth"]=="fake"]["glow_mean"])

# %%
sns.set_context(context='poster', font_scale=0.8)

pair_plot_attribute = sns.pairplot(all_attributes_wide, hue = 'ground_truth', 
             diag_kind = 'hist', markers=["o", "o"],
             palette=real_fake_color_palette,
             hue_order = real_fake_hue_order,
             plot_kws = {'alpha': 0.6, 's': 200, 'edgecolor': 'k'},
             diag_kws = {'alpha': 0.3, 'binwidth' : 0.2, 'multiple' : "dodge", 'kde':False},
             #diag_kws = {'alpha': 0.3, 'binwidth' : 1, 'multiple' : "dodge", 'kde':False},
             grid_kws=dict(diag_sharey=False),                      
             height = 5, corner = True)
#pair_plot_attribute = sns.PairGrid(all_attributes_wide, hue="ground_truth",corner = True)
# pair_plot_attribute = pair_plot_attribute.map_offdiag(sns.scatterplot, markers=["o", "s"], 
#                                                       palette=real_fake_color_palette,
#                                                       hue_order = real_fake_hue_order,
#                                                       alpha = 0.6, s= 50, edgecolor = 'k')
#pair_plot_attribute = pair_plot_attribute.map_diag(sns.catplot)

#pair_plot_attribute = pair_plot_attribute.map_diag(my_hist)

pair_plot_attribute = pair_plot_attribute.map_lower(corrfunc)
pair_plot_attribute = pair_plot_attribute.set(xlim=(0, 1), ylim=(0, 1))
#pair_plot_attribute = pair_plot_attribute.set(xlim=(1, 7), ylim=(1, 7))


# xlabel = range(1,8)
# for ax in pair_plot_attribute.axes.flatten():
#     if ax:
#         ax.set_xticks(xlabel)

# %% [markdown]
# # Show images

# %%
all_attributes_wide[all_attributes_wide["ground_truth"] == "fake"].sort_values(by=['translucency_mean'])
# Out:
#                       image_name  \
# 302  encoded_Group2_IMG_0545.jpg
# 200  encoded_Group2_IMG_9681.jpg
# 139  encoded_Group2_IMG_0139.jpg
# 34   encoded_Group2_IMG_1025.jpg
# 115  encoded_Group2_IMG_5433.jpg
# ..                           ...
# 155  encoded_Group2_IMG_0155.jpg
# 165  encoded_Group2_IMG_9736.jpg
# 66   encoded_Group2_IMG_9726.jpg
# 212  encoded_Group2_IMG_0441.jpg
# 32   encoded_Group2_IMG_0434.jpg
#
#                                             image_path ground_truth  \
# 302  Group1-stimuli/group1-block2/fake-group2-b2/en...         fake
# 200  Group1-stimuli/group1-block2/fake-group2-b2/en...         fake
# 139  Group1-stimuli/group1-block1/fake-group2-b1/en...         fake
# 34   Group1-stimuli/group1-block1/fake-group2-b1/en...         fake
# 115  Group1-stimuli/group1-block1/fake-group2-b1/en...         fake
# ..                                                 ...          ...
# 155  Group1-stimuli/group1-block2/fake-group2-b2/en...         fake
# ...

# %% [markdown]
# # Combine SAR with Real-fake judgement

# %%
#real_fake_error = pd.read_csv("/Users/chenxiliao/Dropbox/Projects/StyleGAN2-ada Translucency/analysis/real_fake_error.csv")
real_fake_error = pd.read_csv("/Users/chenxiliao/Dropbox/Projects/StyleGAN2-ada Translucency/analysis/real_fake_error.csv")

# %%
all_attributes_wide

# %%
real_fake_error

# %%
SAR_real_fake = all_attributes_wide.merge(real_fake_error, how='left', on='image_name')
SAR_real_fake["wrong_percentage"] = SAR_real_fake["num_wrong"]/(SAR_real_fake["num_wrong"] + SAR_real_fake["num_correct"])
SAR_real_fake["correct_percentage"] = 1 - SAR_real_fake["wrong_percentage"]
SAR_real_fake.sort_values(by=['wrong_percentage'])
# Out:
#                       image_name  \
# 130          Group1_IMG_0885.jpg
# 106          Group1_IMG_2231.jpg
# 203          Group1_IMG_1476.jpg
# 119  encoded_Group2_IMG_0100.jpg
# 211          Group1_IMG_1346.jpg
# ..                           ...
# 270  encoded_Group2_IMG_0074.jpg
# 208          Group1_IMG_9774.jpg
# 66           Group1_IMG_1029.jpg
# 140          Group1_IMG_0024.jpg
# 124          Group1_IMG_9889.jpg
#
#                                             image_path ground_truth  \
# 130  Group1-stimuli/group1-block1/real-group1-b1/Gr...         real
# 106  Group1-stimuli/group1-block1/real-group1-b1/Gr...         real
# 203  Group1-stimuli/group1-block2/real-group1-b2/Gr...         real
# 119  Group1-stimuli/group1-block1/fake-group2-b1/en...         fake
# 211  Group1-stimuli/group1-block2/real-group1-b2/Gr...         real
# ..                                                 ...          ...
# 270  Group1-stimuli/group1-block2/fake-group2-b2/en...         fake
# ...

# %%
def plot_heatmap(stimuli_type, attribute, color_map):
    fig, ax = plt.subplots()
    fig.set_size_inches(5, 5)
    
    plot = sns.histplot(data=SAR_real_fake[SAR_real_fake["ground_truth"] == stimuli_type], 
                 x=attribute, y="correct_percentage", multiple="dodge",binwidth = (0.5,0.1),shrink=.8,
                 edgecolor = "white", color = color_map, vmin=2, vmax=16, cbar = True)

#     plot = sns.jointplot(data=SAR_real_fake[SAR_real_fake["ground_truth"] == stimuli_type],
#                          x=attribute, y="correct_percentage", height=5, ratio=2, marginal_ticks=True)

    plot.set(ylim=(0, 1))
    plt.xticks([0, 0.2, 0.4, 0.6, 0.8, 1])
    plt.xticks([0, 0.2, 0.4, 0.6, 0.8, 1])
    sns.despine()

# %%
for i in ["translucency_mean", "see_throughness_mean", "glow_mean"]:
    plot_heatmap("real", i, "purple")

# %%
for i in ["translucency_mean", "see_throughness_mean", "glow_mean"]:
    plot_heatmap("fake", i, "gray")

# %%
conditions_percentage_wrong = [
    (SAR_real_fake['wrong_percentage'] <= 0.25),
    (SAR_real_fake['wrong_percentage'] > 0.25) & (SAR_real_fake['wrong_percentage'] <= 0.5),
    (SAR_real_fake['wrong_percentage'] > 0.5) & (SAR_real_fake['wrong_percentage'] <= 0.75),
    (SAR_real_fake['wrong_percentage'] > 0.75)
    ]

conditions_percentage_wrong2 = [
    (SAR_real_fake['wrong_percentage'] < 0.5),
    (SAR_real_fake['wrong_percentage'] >= 0.5)
    ]


def sar_rating_condition(attribute):
    conditions_sar_rating = [
        (SAR_real_fake[[attribute]] <=0.25),
        (SAR_real_fake[[attribute]] > 0.25) & (SAR_real_fake[[attribute]] <= 0.5),
        (SAR_real_fake[[attribute]] > 0.5) & (SAR_real_fake[[attribute]] <= 75),
        (SAR_real_fake[[attribute]] > 0.75)
        ]
    return conditions_sar_rating


# create a list of the values we want to assign for each condition
values = ['<=25%', '25-50%', '50-75%', '75%+']
values_50 = ['<50%', '50%+']
values_sar = ['low', 'medium', 'high']

# create a new column and use np.select to assign values to it using our lists as arguments
SAR_real_fake['wrong_percentage_tier'] = np.select(conditions_percentage_wrong, values)
SAR_real_fake['translucent_rate'] = np.select(sar_rating_condition("translucency_mean"), values)
SAR_real_fake['see_throughness_rate'] = np.select(sar_rating_condition("see_throughness_mean"), values)
SAR_real_fake['glow_rate'] = np.select(sar_rating_condition("glow_mean"), values)

SAR_real_fake
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-cf2fbbae7d68> in <module>
#       1 conditions_percentage_wrong = [
# ----> 2     (SAR_real_fake['wrong_percentage'] <= 0.25),
#       3     (SAR_real_fake['wrong_percentage'] > 0.25) & (SAR_real_fake['wrong_percentage'] <= 0.5),
#       4     (SAR_real_fake['wrong_percentage'] > 0.5) & (SAR_real_fake['wrong_percentage'] <= 0.75),
#       5     (SAR_real_fake['wrong_percentage'] > 0.75)
#
# NameError: name 'SAR_real_fake' is not defined

# %%
fig, ax = plt.subplots()
fig.set_size_inches(8, 5)

plot1 = sns.violinplot(x="wrong_percentage_tier", y="translucency_mean", hue="ground_truth", inner=None,
                       data= SAR_real_fake[SAR_real_fake.wrong_percentage_tier != "75%+"], hue_order=real_fake_hue_order, scale="count", split=False,
                       palette=real_fake_color_palette, saturation = 0.5, cut = 0)
plot1 = sns.swarmplot(x="wrong_percentage_tier", y="translucency_mean",hue="ground_truth", dodge=True, data=SAR_real_fake[SAR_real_fake.wrong_percentage_tier != "75%+"],
                   color="white", edgecolor="gray",palette=dict(real="white", fake="white"), size=4.5)

sns.move_legend(plot1, "upper left", bbox_to_anchor=(1, 1), title='Groun truth')
sns.despine()

# %%
def plot_heatmap(data, classification_type, index_type, attribute, color_map, max_count):
    
    

    sar_crosstab = pd.crosstab(data[classification_type],
                                data[attribute], 
                                   margins = False)
    
    chi2_statistic, p_value, dof, ex = stats.chi2_contingency(np.array(sar_crosstab))
    print("p-value for chi-squared test:",p_value)

    sar_crosstab = sar_crosstab.reindex(['<=25%', '25-50%', '50-75%', '75%+'], axis="columns")
    sar_crosstab = sar_crosstab.reindex(index_type, axis="rows")

    heatmap = sns.heatmap(sar_crosstab, annot=True, cmap=color_map, linewidths=.5, square=True,  vmax=max_count)
    
    
encoded = SAR_real_fake[SAR_real_fake["ground_truth"] == "fake"]
index_percent_wrong = ["<=25%", "25-50%", "50-75%"]
index_percent_ground_truth = ["real", "fake"]

plot_heatmap(encoded, "wrong_percentage_tier", index_percent_wrong,"translucent_rate", "Greens", 50)

# SAR_real_fake[SAR_real_fake["ground_truth"] == "fake"]

# ax2 = SAR_real_fake[SAR_real_fake["ground_truth"] == "fake"].plot.scatter(x='tier',
#                        y='translucency_mean')
# Out:
# p-value for chi-squared test: 0.7538981975439347

# %%
plot_heatmap(encoded, "wrong_percentage_tier", index_percent_wrong,"see_throughness_rate", "Blues", 50)

# %%
plot_heatmap(encoded, "wrong_percentage_tier", index_percent_wrong,"glow_rate", "Oranges", 50)

# %%
SAR_real_fake

# %%
#plot_heatmap(SAR_real_fake, "ground_truth", index_percent_ground_truth,"see_throughness_rate", "Purples", 100)
#plot_heatmap(SAR_real_fake, "ground_truth", index_percent_ground_truth,"glow_rate", "Purples", 100)
plot_heatmap(SAR_real_fake, "ground_truth", index_percent_ground_truth,"translucent_rate", "Purples", 100)
# Out:
# p-value for chi-squared test: 0.0834698046678378

# %% [markdown]
# # Compare with SVM prediction

# %%
def annotate_scatter(data, **kws):
    x = data['mean_rating']
    y = data['dist_norm']
    r, p = stats.pearsonr(x, y)
#     r, p = stats.spearmanr(x, y)
    r, p = round(r,2), round(p,3)
    ax = plt.gca()
    ax.text(.1, .9, f"r = {r}, p = {p}", transform=ax.transAxes)

# %%
def plot_svm_predict(file_name):
    #print(os.path.basename(file_name))
    svm_prediction = pd.read_csv(file_name)
    svm_vs_human = all_attributes_wide[all_attributes_wide["ground_truth"] == "fake"].merge(svm_prediction, how='left', on='image_name')

    svm_vs_human["dist_norm"] = (svm_vs_human["distance_bound"]-svm_vs_human["distance_bound"].min())/(svm_vs_human["distance_bound"].max()-svm_vs_human["distance_bound"].min())
    
    r_tran, _ = stats.pearsonr(svm_vs_human['translucency_mean'], svm_vs_human["dist_norm"])  
    r_see, _ = stats.pearsonr(svm_vs_human['see_throughness_mean'], svm_vs_human["dist_norm"])  
    r_glow, _ = stats.pearsonr(svm_vs_human['glow_mean'], svm_vs_human["dist_norm"])  

    #print(svm_vs_human)
    
    svm_vs_human_long =  pd.melt(svm_vs_human, id_vars=['image_name','image_path','ground_truth','distance_bound','dist_norm','predicted'],
                                var_name='attribute', value_name='mean_rating',
                value_vars=['translucency_mean', 'see_throughness_mean','glow_mean'])
    
    
    file_name = os.path.basename(file_name)
    sns.color_palette("rocket", as_cmap=True)
    g = sns.FacetGrid(svm_vs_human_long, col="attribute", margin_titles=False, hue = "attribute", hue_order = ["see_throughness_mean","glow_mean", "translucency_mean"],
                      hue_kws=dict(marker=["X", "s", "o"]),
                     palette = "deep")

    g.map_dataframe(sns.scatterplot, x="dist_norm", y="mean_rating", s = 70, alpha = 1)
    g.map_dataframe(annotate_scatter)
    g.set(ylabel='Mean attribute rating', ylim=(0, 1))
    #g.set(ylabel='Mean attribute rating', ylim=(1, 7))
    #plt.xticks([0, 0.2, 0.4, 0.6, 0.8, 1])
    plt.xticks([0, 0.5, 1])
    plt.yticks([0, 0.5, 1])
    g.fig.suptitle(file_name)
    #g.add_legend()

    return r_tran, r_see, r_glow

# %%
#file_path_svm_pred = "/Users/chenxiliao/Dropbox/Projects/StyleGAN2-ada Translucency/analysis/layer_predict/svm_prediction_"

def plot_r_trend(file_path):
    layer_names, r_trans_layers, r_see_layers, r_glow_layers= [],[],[],[]
    for i in range(18):
        layer_name = str(i)
        path = file_path + str(i) + ".csv"
        r_tran, r_see, r_glow = plot_svm_predict(path)

        layer_names.append(layer_name)
        r_trans_layers.append(np.abs(r_tran))
        r_see_layers.append(np.abs(r_see))
        r_glow_layers.append(np.abs(r_glow))

    r_table = pd.DataFrame({'layer_name':layer_names,
                            'translucent': r_trans_layers,
                            'see-throughness':r_see_layers,
                            'glow':r_glow_layers

    })

    return r_table

# %%
#file_path_svm_pred = "/Users/wesliao/Dropbox/Projects/StyleGAN2-ada Translucency/analysis/layer_predict_flip/svm_prediction_"
sns.set_context(context='poster', font_scale=0.5)
#file_path_svm_pred = "../analysis/layer_predict_flip/svm_prediction_"
file_path_svm_pred = "../analysis/svm_c001/svm_prediction_"


r_table = plot_r_trend(file_path_svm_pred)

# %%
r_trend_long = r_table.melt('layer_name', var_name='attribute', value_name='correlation')


xlabel = list(r_table["layer_name"])
#r_trend = sns.lineplot(data=r_table.iloc[: , :2], marker = "o", dashes = [(2,2)])

fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(10, 7)

sns.set_context(context='poster', font_scale=1)
r_trend = sns.lineplot(
                        data=r_trend_long,
                        x="layer_name", y="correlation", hue="attribute", style="attribute",
                        markers=True, dashes=True, alpha  = 0.9, markersize=20,
                        palette="deep", hue_order = ["see-throughness","glow", "translucent"],
    
                    )
# plt.xticks(rotation=90)
ticks_val = range(18)
tick_val_str = [str(i+1) for i in ticks_val]


plt.xticks(ticks = ticks_val,labels = tick_val_str, rotation=90, fontsize=20)
sns.move_legend(r_trend, "upper left", bbox_to_anchor=(1, 1), title='Attribute')
sns.despine()
# r_trend.set(xlabel='Layer of W+ latent space', ylabel='Correlation',
#                            title='Changes of correlation across layers')

# %%
tick_val_str

# %%
layer6_info = pd.read_csv("/Users/chenxiliao/Dropbox/Projects/StyleGAN2-ada Translucency/analysis/layer_predict_dist/svm_prediction_6.csv")

# %%
layer6_info

# %%
layer8_info = pd.read_csv("/Users/chenxiliao/Dropbox/Projects/StyleGAN2-ada Translucency/analysis/layer_predict_dist/svm_prediction_8.csv")
layer8_info

# %%
from sklearn.datasets import make_blobs
X, y = make_blobs(n_samples=40, centers=2, random_state=6)
X.shape
