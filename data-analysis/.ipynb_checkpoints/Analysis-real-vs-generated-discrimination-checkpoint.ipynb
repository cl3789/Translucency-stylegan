# %%
import pandas as pd
import numpy as np
import os
import fnmatch, re

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score,pairwise_distances

import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats
from scipy.stats import pearsonr

import altair as alt

# %%
def compute_error_rate(df):
    conf_mat = confusion_matrix(df["ground_truth"], df["Judgement.keys"], labels=["real", "fake"])
    row,_ = df.shape
    num_category = row/2
    print(row)
    real_err_rate = conf_mat[0,1]/num_category
    fake_err_rate = conf_mat[1,0]/num_category
    print(conf_mat)
    print("Error rate for real images:", real_err_rate)
    print("Error rate for fake images:", fake_err_rate)
    
    accuracy = accuracy_score(df["ground_truth"], df["Judgement.keys"])
    
    return accuracy, real_err_rate, fake_err_rate

def drop_demos(data):
    data = data.drop(range(0,3))
    data['ground_truth'] = data['ground_truth'].astype(int)
    data = data.replace(0,"fake")
    data = data.replace(1,"real")
    return data

def process_individual(file_path, file_name):
    participant_file_path = os.path.join(file_path, file_name)
    participant_data = pd.read_csv(participant_file_path)
    participant_data = drop_demos(participant_data)
    participant_data["result"] = participant_data.apply(lambda x: "correct" if x['ground_truth'] == x['Judgement.keys'] else "wrong", axis=1)
    data = participant_data[["Trial_num","image_name","image_path","ground_truth","Judgement.keys","result"]]
    rep1 = data.iloc[0:300]
    rep2 = data.iloc[300:]
    
    select_fake_rep1,_ = rep1[rep1["Judgement.keys"] == "fake"].shape
    #print(select_fake_rep1)
 
    select_fake_rep2,_ = rep2[rep2["Judgement.keys"] == "fake"].shape
    #print(select_fake_rep2)
    
    
    print("Repetition 1:")
    accuracy_rep1, real_err_rate_rep1, fake_err_rate_rep1 = compute_error_rate(rep1)
    print("Repetition 2:")
    accuracy_rep2, real_err_rate_rep2, fake_err_rate_rep2 = compute_error_rate(rep2)
    print("Overall:")
    accuracy_all, real_err_rate_all, fake_err_rate_all = compute_error_rate(data)

    
    wrong_rep1 = rep1[rep1["result"] == "wrong"]["image_name"]
    wrong_rep2 = rep2[rep2["result"] == "wrong"]["image_name"]

    wrong_in_both = list(set(wrong_rep1).intersection(wrong_rep2))
    print("Wrong in both:",len(wrong_in_both))
    
    encoded_misjudged = list(filter(lambda x: x.startswith('encoded'), wrong_in_both))
    
    real_misjudged = list(set(wrong_in_both) - set(encoded_misjudged))
    
    print("Number of encoded image been misjudged in both repetition:", len(encoded_misjudged)/150)
    print("Number of real image been misjudged in both repetition:", len(real_misjudged)/150)
    
    df_person = pd.DataFrame({'participant':file_name,
                              'real_err_rate_rep1':real_err_rate_rep1,
                              'fake_err_rate_rep1':fake_err_rate_rep1,
                              'real_err_rate_rep2':real_err_rate_rep2,
                              'fake_err_rate_rep2':fake_err_rate_rep2,
                              'real_err_rate_all':real_err_rate_all,
                              'fake_err_rate_all':fake_err_rate_all,
                              'accuracy_rep1': accuracy_rep1,
                              'accuracy_rep2': accuracy_rep2,
                              'accuracy_all': accuracy_all,
                              'select_fake_rep1':select_fake_rep1,
                              'select_fake_rep2':select_fake_rep2,
                              'real_misjudged_img_both_rep':[real_misjudged], 
                              'encoded_misjudged_img_both_rep':[encoded_misjudged], 
                              'num_real_misjudged_both_rep':len(real_misjudged),
                              'num_encoded_misjudged_both_rep':len(encoded_misjudged)}) 
    
    
    person_result = data[["result"]]
    
    return df_person, person_result


def process_all_people(file_path):
    files = list(filter(lambda f: os.path.isfile(os.path.join(file_path,f)), os.listdir(file_path)))

    df_stat = pd.DataFrame()
    
    trial_num_path = os.path.join(file_path, files[0])
    print(trial_num_path)
    
    aggregate = pd.read_csv(trial_num_path, usecols = ["Trial_num","image_name","image_path","ground_truth"])
    aggregate = drop_demos(aggregate)
    
    for person_data in files:
        if fnmatch.fnmatch(person_data, '*.csv'):
            df_person, person_result = process_individual(file_path, person_data)
            df_stat = df_stat.append(df_person, ignore_index=True)
            aggregate = pd.concat([aggregate, person_result], axis=1)
            print(aggregate)

    aggregate["all_res"] =  aggregate[aggregate.columns[4]].values.tolist()
    aggregate["num_correct"] = aggregate['all_res'].apply(lambda x: x.count("correct"))
    aggregate["num_wrong"] = aggregate['all_res'].apply(lambda x: x.count("wrong"))
    return df_stat,  aggregate

# %%
## Read the data
data_path = "data/Experiment1"
all_people_real_fake, aggregate_result = process_all_people(data_path)
# Out:
# data/Experiment1/6.csv
# Repetition 1:
# 300
# [[107  43]
#  [ 23 127]]
# Error rate for real images: 0.2866666666666667
# Error rate for fake images: 0.15333333333333332
# Repetition 2:
# 300
# [[120  30]
#  [ 20 130]]
# Error rate for real images: 0.2
# Error rate for fake images: 0.13333333333333333
# Overall:
# 600
# [[227  73]
#  [ 43 257]]
# Error rate for real images: 0.24333333333333335
# Error rate for fake images: 0.14333333333333334
# Wrong in both: 19
# Number of encoded image been misjudged in both repetition: 0.03333333333333333
# Number of real image been misjudged in both repetition: 0.09333333333333334
#        Trial_num                                         image_path  \
# 3      Trial # 1  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 4      Trial # 2  Group1-stimuli/group1-block1/fake-group2-b1/en...
# 5      Trial # 3  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 6      Trial # 4  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 7      Trial # 5  Group1-stimuli/group1-block1/fake-group2-b1/en...
# ..           ...                                                ...
# 598  Trial # 146  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 599  Trial # 147  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 600  Trial # 148  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 601  Trial # 149  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 602  Trial # 150  Group1-stimuli/group1-block2/fake-group2-b2/en...
#
#     ground_truth                   image_name   result
# 3           real          Group1_IMG_0022.jpg  correct
# 4           fake  encoded_Group2_IMG_0386.jpg  correct
# 5           real          Group1_IMG_9704.jpg    wrong
# 6           real          Group1_IMG_0406.jpg  correct
# 7           fake  encoded_Group2_IMG_0364.jpg  correct
# ..           ...                          ...      ...
# 598         fake  encoded_Group2_IMG_9935.jpg  correct
# 599         real          Group1_IMG_9897.jpg  correct
# 600         real          Group1_IMG_0453.jpg  correct
# 601         fake  encoded_Group2_IMG_0308.jpg  correct
# 602         fake  encoded_Group2_IMG_0249.jpg  correct
#
# [600 rows x 5 columns]
# Repetition 1:
# 300
# [[121  29]
#  [ 52  98]]
# Error rate for real images: 0.19333333333333333
# Error rate for fake images: 0.3466666666666667
# Repetition 2:
# 300
# [[130  20]
#  [ 59  91]]
# Error rate for real images: 0.13333333333333333
# Error rate for fake images: 0.3933333333333333
# Overall:
# 600
# [[251  49]
#  [111 189]]
# Error rate for real images: 0.16333333333333333
# Error rate for fake images: 0.37
# Wrong in both: 39
# Number of encoded image been misjudged in both repetition: 0.19333333333333333
# Number of real image been misjudged in both repetition: 0.06666666666666667
#        Trial_num                                         image_path  \
# 3      Trial # 1  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 4      Trial # 2  Group1-stimuli/group1-block1/fake-group2-b1/en...
# 5      Trial # 3  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 6      Trial # 4  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 7      Trial # 5  Group1-stimuli/group1-block1/fake-group2-b1/en...
# ..           ...                                                ...
# 598  Trial # 146  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 599  Trial # 147  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 600  Trial # 148  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 601  Trial # 149  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 602  Trial # 150  Group1-stimuli/group1-block2/fake-group2-b2/en...
#
#     ground_truth                   image_name   result   result
# 3           real          Group1_IMG_0022.jpg  correct  correct
# 4           fake  encoded_Group2_IMG_0386.jpg  correct  correct
# 5           real          Group1_IMG_9704.jpg    wrong  correct
# 6           real          Group1_IMG_0406.jpg  correct  correct
# 7           fake  encoded_Group2_IMG_0364.jpg  correct  correct
# ..           ...                          ...      ...      ...
# 598         fake  encoded_Group2_IMG_9935.jpg  correct    wrong
# 599         real          Group1_IMG_9897.jpg  correct  correct
# 600         real          Group1_IMG_0453.jpg  correct  correct
# 601         fake  encoded_Group2_IMG_0308.jpg  correct  correct
# 602         fake  encoded_Group2_IMG_0249.jpg  correct    wrong
#
# [600 rows x 6 columns]
# Repetition 1:
# 300
# [[ 89  61]
#  [ 43 107]]
# Error rate for real images: 0.4066666666666667
# Error rate for fake images: 0.2866666666666667
# Repetition 2:
# 300
# [[ 99  51]
#  [ 45 105]]
# Error rate for real images: 0.34
# Error rate for fake images: 0.3
# Overall:
# 600
# [[188 112]
#  [ 88 212]]
# Error rate for real images: 0.37333333333333335
# Error rate for fake images: 0.29333333333333333
# Wrong in both: 49
# Number of encoded image been misjudged in both repetition: 0.12666666666666668
# Number of real image been misjudged in both repetition: 0.2
#        Trial_num                                         image_path  \
# 3      Trial # 1  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 4      Trial # 2  Group1-stimuli/group1-block1/fake-group2-b1/en...
# 5      Trial # 3  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 6      Trial # 4  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 7      Trial # 5  Group1-stimuli/group1-block1/fake-group2-b1/en...
# ..           ...                                                ...
# 598  Trial # 146  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 599  Trial # 147  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 600  Trial # 148  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 601  Trial # 149  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 602  Trial # 150  Group1-stimuli/group1-block2/fake-group2-b2/en...
#
#     ground_truth                   image_name   result   result   result
# 3           real          Group1_IMG_0022.jpg  correct  correct  correct
# 4           fake  encoded_Group2_IMG_0386.jpg  correct  correct  correct
# 5           real          Group1_IMG_9704.jpg    wrong  correct    wrong
# 6           real          Group1_IMG_0406.jpg  correct  correct  correct
# 7           fake  encoded_Group2_IMG_0364.jpg  correct  correct  correct
# ..           ...                          ...      ...      ...      ...
# 598         fake  encoded_Group2_IMG_9935.jpg  correct    wrong  correct
# 599         real          Group1_IMG_9897.jpg  correct  correct  correct
# 600         real          Group1_IMG_0453.jpg  correct  correct  correct
# 601         fake  encoded_Group2_IMG_0308.jpg  correct  correct  correct
# 602         fake  encoded_Group2_IMG_0249.jpg  correct    wrong  correct
#
# [600 rows x 7 columns]
# Repetition 1:
# 300
# [[66 84]
#  [56 94]]
# Error rate for real images: 0.56
# Error rate for fake images: 0.37333333333333335
# Repetition 2:
# 300
# [[70 80]
#  [57 93]]
# Error rate for real images: 0.5333333333333333
# Error rate for fake images: 0.38
# Overall:
# 600
# [[136 164]
#  [113 187]]
# Error rate for real images: 0.5466666666666666
# Error rate for fake images: 0.37666666666666665
# Wrong in both: 85
# Number of encoded image been misjudged in both repetition: 0.19333333333333333
# Number of real image been misjudged in both repetition: 0.37333333333333335
#        Trial_num                                         image_path  \
# 3      Trial # 1  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 4      Trial # 2  Group1-stimuli/group1-block1/fake-group2-b1/en...
# 5      Trial # 3  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 6      Trial # 4  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 7      Trial # 5  Group1-stimuli/group1-block1/fake-group2-b1/en...
# ..           ...                                                ...
# 598  Trial # 146  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 599  Trial # 147  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 600  Trial # 148  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 601  Trial # 149  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 602  Trial # 150  Group1-stimuli/group1-block2/fake-group2-b2/en...
#
#     ground_truth                   image_name   result   result   result  \
# 3           real          Group1_IMG_0022.jpg  correct  correct  correct
# 4           fake  encoded_Group2_IMG_0386.jpg  correct  correct  correct
# 5           real          Group1_IMG_9704.jpg    wrong  correct    wrong
# 6           real          Group1_IMG_0406.jpg  correct  correct  correct
# 7           fake  encoded_Group2_IMG_0364.jpg  correct  correct  correct
# ..           ...                          ...      ...      ...      ...
# 598         fake  encoded_Group2_IMG_9935.jpg  correct    wrong  correct
# 599         real          Group1_IMG_9897.jpg  correct  correct  correct
# 600         real          Group1_IMG_0453.jpg  correct  correct  correct
# 601         fake  encoded_Group2_IMG_0308.jpg  correct  correct  correct
# 602         fake  encoded_Group2_IMG_0249.jpg  correct    wrong  correct
#
#       result
# 3    correct
# 4      wrong
# 5      wrong
# 6      wrong
# 7    correct
# ..       ...
# 598    wrong
# 599  correct
# 600    wrong
# 601  correct
# 602    wrong
#
# [600 rows x 8 columns]
# Repetition 1:
# 300
# [[109  41]
#  [ 48 102]]
# Error rate for real images: 0.2733333333333333
# Error rate for fake images: 0.32
# Repetition 2:
# 300
# [[94 56]
#  [67 83]]
# Error rate for real images: 0.37333333333333335
# Error rate for fake images: 0.44666666666666666
# Overall:
# 600
# [[203  97]
#  [115 185]]
# Error rate for real images: 0.3233333333333333
# Error rate for fake images: 0.38333333333333336
# Wrong in both: 49
# Number of encoded image been misjudged in both repetition: 0.18
# Number of real image been misjudged in both repetition: 0.14666666666666667
#        Trial_num                                         image_path  \
# 3      Trial # 1  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 4      Trial # 2  Group1-stimuli/group1-block1/fake-group2-b1/en...
# 5      Trial # 3  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 6      Trial # 4  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 7      Trial # 5  Group1-stimuli/group1-block1/fake-group2-b1/en...
# ..           ...                                                ...
# 598  Trial # 146  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 599  Trial # 147  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 600  Trial # 148  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 601  Trial # 149  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 602  Trial # 150  Group1-stimuli/group1-block2/fake-group2-b2/en...
#
#     ground_truth                   image_name   result   result   result  \
# 3           real          Group1_IMG_0022.jpg  correct  correct  correct
# 4           fake  encoded_Group2_IMG_0386.jpg  correct  correct  correct
# 5           real          Group1_IMG_9704.jpg    wrong  correct    wrong
# 6           real          Group1_IMG_0406.jpg  correct  correct  correct
# 7           fake  encoded_Group2_IMG_0364.jpg  correct  correct  correct
# ..           ...                          ...      ...      ...      ...
# 598         fake  encoded_Group2_IMG_9935.jpg  correct    wrong  correct
# 599         real          Group1_IMG_9897.jpg  correct  correct  correct
# 600         real          Group1_IMG_0453.jpg  correct  correct  correct
# 601         fake  encoded_Group2_IMG_0308.jpg  correct  correct  correct
# 602         fake  encoded_Group2_IMG_0249.jpg  correct    wrong  correct
#
#       result   result
# 3    correct  correct
# 4      wrong  correct
# 5      wrong  correct
# 6      wrong  correct
# 7    correct  correct
# ..       ...      ...
# 598    wrong    wrong
# 599  correct    wrong
# 600    wrong  correct
# 601  correct  correct
# 602    wrong  correct
#
# [600 rows x 9 columns]
# Repetition 1:
# 300
# [[126  24]
#  [ 28 122]]
# Error rate for real images: 0.16
# Error rate for fake images: 0.18666666666666668
# Repetition 2:
# 300
# [[138  12]
#  [ 36 114]]
# Error rate for real images: 0.08
# Error rate for fake images: 0.24
# Overall:
# 600
# [[264  36]
#  [ 64 236]]
# Error rate for real images: 0.12
# Error rate for fake images: 0.21333333333333335
# Wrong in both: 19
# Number of encoded image been misjudged in both repetition: 0.08666666666666667
# Number of real image been misjudged in both repetition: 0.04
#        Trial_num                                         image_path  \
# 3      Trial # 1  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 4      Trial # 2  Group1-stimuli/group1-block1/fake-group2-b1/en...
# 5      Trial # 3  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 6      Trial # 4  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 7      Trial # 5  Group1-stimuli/group1-block1/fake-group2-b1/en...
# ..           ...                                                ...
# 598  Trial # 146  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 599  Trial # 147  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 600  Trial # 148  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 601  Trial # 149  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 602  Trial # 150  Group1-stimuli/group1-block2/fake-group2-b2/en...
#
#     ground_truth                   image_name   result   result   result  \
# 3           real          Group1_IMG_0022.jpg  correct  correct  correct
# 4           fake  encoded_Group2_IMG_0386.jpg  correct  correct  correct
# 5           real          Group1_IMG_9704.jpg    wrong  correct    wrong
# 6           real          Group1_IMG_0406.jpg  correct  correct  correct
# 7           fake  encoded_Group2_IMG_0364.jpg  correct  correct  correct
# ..           ...                          ...      ...      ...      ...
# 598         fake  encoded_Group2_IMG_9935.jpg  correct    wrong  correct
# 599         real          Group1_IMG_9897.jpg  correct  correct  correct
# 600         real          Group1_IMG_0453.jpg  correct  correct  correct
# 601         fake  encoded_Group2_IMG_0308.jpg  correct  correct  correct
# 602         fake  encoded_Group2_IMG_0249.jpg  correct    wrong  correct
#
#       result   result   result
# 3    correct  correct    wrong
# 4      wrong  correct    wrong
# 5      wrong  correct  correct
# 6      wrong  correct  correct
# 7    correct  correct  correct
# ..       ...      ...      ...
# 598    wrong    wrong    wrong
# 599  correct    wrong  correct
# 600    wrong  correct  correct
# 601  correct  correct  correct
# 602    wrong  correct    wrong
#
# [600 rows x 10 columns]
# Repetition 1:
# 300
# [[121  29]
#  [ 33 117]]
# Error rate for real images: 0.19333333333333333
# Error rate for fake images: 0.22
# Repetition 2:
# 300
# [[118  32]
#  [ 48 102]]
# Error rate for real images: 0.21333333333333335
# Error rate for fake images: 0.32
# Overall:
# 600
# [[239  61]
#  [ 81 219]]
# Error rate for real images: 0.20333333333333334
# Error rate for fake images: 0.27
# Wrong in both: 30
# Number of encoded image been misjudged in both repetition: 0.10666666666666667
# Number of real image been misjudged in both repetition: 0.09333333333333334
#        Trial_num                                         image_path  \
# 3      Trial # 1  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 4      Trial # 2  Group1-stimuli/group1-block1/fake-group2-b1/en...
# 5      Trial # 3  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 6      Trial # 4  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 7      Trial # 5  Group1-stimuli/group1-block1/fake-group2-b1/en...
# ..           ...                                                ...
# 598  Trial # 146  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 599  Trial # 147  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 600  Trial # 148  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 601  Trial # 149  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 602  Trial # 150  Group1-stimuli/group1-block2/fake-group2-b2/en...
#
#     ground_truth                   image_name   result   result   result  \
# 3           real          Group1_IMG_0022.jpg  correct  correct  correct
# 4           fake  encoded_Group2_IMG_0386.jpg  correct  correct  correct
# 5           real          Group1_IMG_9704.jpg    wrong  correct    wrong
# 6           real          Group1_IMG_0406.jpg  correct  correct  correct
# 7           fake  encoded_Group2_IMG_0364.jpg  correct  correct  correct
# ..           ...                          ...      ...      ...      ...
# 598         fake  encoded_Group2_IMG_9935.jpg  correct    wrong  correct
# 599         real          Group1_IMG_9897.jpg  correct  correct  correct
# 600         real          Group1_IMG_0453.jpg  correct  correct  correct
# 601         fake  encoded_Group2_IMG_0308.jpg  correct  correct  correct
# 602         fake  encoded_Group2_IMG_0249.jpg  correct    wrong  correct
#
#       result   result   result   result
# 3    correct  correct    wrong  correct
# 4      wrong  correct    wrong  correct
# 5      wrong  correct  correct    wrong
# 6      wrong  correct  correct  correct
# 7    correct  correct  correct  correct
# ..       ...      ...      ...      ...
# 598    wrong    wrong    wrong    wrong
# 599  correct    wrong  correct  correct
# 600    wrong  correct  correct  correct
# 601  correct  correct  correct  correct
# 602    wrong  correct    wrong  correct
#
# [600 rows x 11 columns]
# Repetition 1:
# 300
# [[108  42]
#  [ 45 105]]
# Error rate for real images: 0.28
# Error rate for fake images: 0.3
# Repetition 2:
# 300
# [[115  35]
#  [ 53  97]]
# Error rate for real images: 0.23333333333333334
# Error rate for fake images: 0.35333333333333333
# Overall:
# 600
# [[223  77]
#  [ 98 202]]
# Error rate for real images: 0.25666666666666665
# Error rate for fake images: 0.32666666666666666
# Wrong in both: 54
# Number of encoded image been misjudged in both repetition: 0.2
# Number of real image been misjudged in both repetition: 0.16
#        Trial_num                                         image_path  \
# 3      Trial # 1  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 4      Trial # 2  Group1-stimuli/group1-block1/fake-group2-b1/en...
# 5      Trial # 3  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 6      Trial # 4  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 7      Trial # 5  Group1-stimuli/group1-block1/fake-group2-b1/en...
# ..           ...                                                ...
# 598  Trial # 146  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 599  Trial # 147  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 600  Trial # 148  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 601  Trial # 149  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 602  Trial # 150  Group1-stimuli/group1-block2/fake-group2-b2/en...
#
#     ground_truth                   image_name   result   result   result  \
# 3           real          Group1_IMG_0022.jpg  correct  correct  correct
# 4           fake  encoded_Group2_IMG_0386.jpg  correct  correct  correct
# 5           real          Group1_IMG_9704.jpg    wrong  correct    wrong
# 6           real          Group1_IMG_0406.jpg  correct  correct  correct
# 7           fake  encoded_Group2_IMG_0364.jpg  correct  correct  correct
# ..           ...                          ...      ...      ...      ...
# 598         fake  encoded_Group2_IMG_9935.jpg  correct    wrong  correct
# 599         real          Group1_IMG_9897.jpg  correct  correct  correct
# 600         real          Group1_IMG_0453.jpg  correct  correct  correct
# 601         fake  encoded_Group2_IMG_0308.jpg  correct  correct  correct
# 602         fake  encoded_Group2_IMG_0249.jpg  correct    wrong  correct
#
#       result   result   result   result   result
# 3    correct  correct    wrong  correct    wrong
# 4      wrong  correct    wrong  correct    wrong
# 5      wrong  correct  correct    wrong    wrong
# 6      wrong  correct  correct  correct  correct
# 7    correct  correct  correct  correct  correct
# ..       ...      ...      ...      ...      ...
# 598    wrong    wrong    wrong    wrong  correct
# 599  correct    wrong  correct  correct  correct
# 600    wrong  correct  correct  correct  correct
# 601  correct  correct  correct  correct  correct
# 602    wrong  correct    wrong  correct  correct
#
# [600 rows x 12 columns]
# Repetition 1:
# 300
# [[114  36]
#  [ 54  96]]
# Error rate for real images: 0.24
# Error rate for fake images: 0.36
# Repetition 2:
# 300
# [[121  29]
#  [ 65  85]]
# Error rate for real images: 0.19333333333333333
# Error rate for fake images: 0.43333333333333335
# Overall:
# 600
# [[235  65]
#  [119 181]]
# Error rate for real images: 0.21666666666666667
# Error rate for fake images: 0.39666666666666667
# Wrong in both: 46
# Number of encoded image been misjudged in both repetition: 0.22
# Number of real image been misjudged in both repetition: 0.08666666666666667
#        Trial_num                                         image_path  \
# 3      Trial # 1  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 4      Trial # 2  Group1-stimuli/group1-block1/fake-group2-b1/en...
# 5      Trial # 3  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 6      Trial # 4  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 7      Trial # 5  Group1-stimuli/group1-block1/fake-group2-b1/en...
# ..           ...                                                ...
# 598  Trial # 146  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 599  Trial # 147  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 600  Trial # 148  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 601  Trial # 149  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 602  Trial # 150  Group1-stimuli/group1-block2/fake-group2-b2/en...
#
#     ground_truth                   image_name   result   result   result  \
# 3           real          Group1_IMG_0022.jpg  correct  correct  correct
# 4           fake  encoded_Group2_IMG_0386.jpg  correct  correct  correct
# 5           real          Group1_IMG_9704.jpg    wrong  correct    wrong
# 6           real          Group1_IMG_0406.jpg  correct  correct  correct
# 7           fake  encoded_Group2_IMG_0364.jpg  correct  correct  correct
# ..           ...                          ...      ...      ...      ...
# 598         fake  encoded_Group2_IMG_9935.jpg  correct    wrong  correct
# 599         real          Group1_IMG_9897.jpg  correct  correct  correct
# 600         real          Group1_IMG_0453.jpg  correct  correct  correct
# 601         fake  encoded_Group2_IMG_0308.jpg  correct  correct  correct
# 602         fake  encoded_Group2_IMG_0249.jpg  correct    wrong  correct
#
#       result   result   result   result   result   result
# 3    correct  correct    wrong  correct    wrong  correct
# 4      wrong  correct    wrong  correct    wrong  correct
# 5      wrong  correct  correct    wrong    wrong    wrong
# 6      wrong  correct  correct  correct  correct  correct
# 7    correct  correct  correct  correct  correct  correct
# ..       ...      ...      ...      ...      ...      ...
# 598    wrong    wrong    wrong    wrong  correct    wrong
# 599  correct    wrong  correct  correct  correct  correct
# 600    wrong  correct  correct  correct  correct  correct
# 601  correct  correct  correct  correct  correct  correct
# 602    wrong  correct    wrong  correct  correct    wrong
#
# [600 rows x 13 columns]
# Repetition 1:
# 300
# [[124  26]
#  [ 46 104]]
# Error rate for real images: 0.17333333333333334
# Error rate for fake images: 0.30666666666666664
# Repetition 2:
# 300
# [[126  24]
#  [ 30 120]]
# Error rate for real images: 0.16
# Error rate for fake images: 0.2
# Overall:
# 600
# [[250  50]
#  [ 76 224]]
# Error rate for real images: 0.16666666666666666
# Error rate for fake images: 0.25333333333333335
# Wrong in both: 25
# Number of encoded image been misjudged in both repetition: 0.10666666666666667
# Number of real image been misjudged in both repetition: 0.06
#        Trial_num                                         image_path  \
# 3      Trial # 1  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 4      Trial # 2  Group1-stimuli/group1-block1/fake-group2-b1/en...
# 5      Trial # 3  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 6      Trial # 4  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 7      Trial # 5  Group1-stimuli/group1-block1/fake-group2-b1/en...
# ..           ...                                                ...
# 598  Trial # 146  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 599  Trial # 147  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 600  Trial # 148  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 601  Trial # 149  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 602  Trial # 150  Group1-stimuli/group1-block2/fake-group2-b2/en...
#
#     ground_truth                   image_name   result   result   result  \
# 3           real          Group1_IMG_0022.jpg  correct  correct  correct
# 4           fake  encoded_Group2_IMG_0386.jpg  correct  correct  correct
# 5           real          Group1_IMG_9704.jpg    wrong  correct    wrong
# 6           real          Group1_IMG_0406.jpg  correct  correct  correct
# 7           fake  encoded_Group2_IMG_0364.jpg  correct  correct  correct
# ..           ...                          ...      ...      ...      ...
# 598         fake  encoded_Group2_IMG_9935.jpg  correct    wrong  correct
# 599         real          Group1_IMG_9897.jpg  correct  correct  correct
# 600         real          Group1_IMG_0453.jpg  correct  correct  correct
# 601         fake  encoded_Group2_IMG_0308.jpg  correct  correct  correct
# 602         fake  encoded_Group2_IMG_0249.jpg  correct    wrong  correct
#
#       result   result   result   result   result   result   result
# 3    correct  correct    wrong  correct    wrong  correct    wrong
# 4      wrong  correct    wrong  correct    wrong  correct    wrong
# 5      wrong  correct  correct    wrong    wrong    wrong    wrong
# 6      wrong  correct  correct  correct  correct  correct  correct
# 7    correct  correct  correct  correct  correct  correct  correct
# ..       ...      ...      ...      ...      ...      ...      ...
# 598    wrong    wrong    wrong    wrong  correct    wrong    wrong
# 599  correct    wrong  correct  correct  correct  correct  correct
# 600    wrong  correct  correct  correct  correct  correct  correct
# 601  correct  correct  correct  correct  correct  correct  correct
# 602    wrong  correct    wrong  correct  correct    wrong  correct
#
# [600 rows x 14 columns]
# Repetition 1:
# 300
# [[124  26]
#  [ 39 111]]
# Error rate for real images: 0.17333333333333334
# Error rate for fake images: 0.26
# Repetition 2:
# 300
# [[138  12]
#  [ 46 104]]
# Error rate for real images: 0.08
# Error rate for fake images: 0.30666666666666664
# Overall:
# 600
# [[262  38]
#  [ 85 215]]
# Error rate for real images: 0.12666666666666668
# Error rate for fake images: 0.2833333333333333
# Wrong in both: 28
# Number of encoded image been misjudged in both repetition: 0.14
# Number of real image been misjudged in both repetition: 0.04666666666666667
#        Trial_num                                         image_path  \
# 3      Trial # 1  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 4      Trial # 2  Group1-stimuli/group1-block1/fake-group2-b1/en...
# 5      Trial # 3  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 6      Trial # 4  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 7      Trial # 5  Group1-stimuli/group1-block1/fake-group2-b1/en...
# ..           ...                                                ...
# 598  Trial # 146  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 599  Trial # 147  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 600  Trial # 148  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 601  Trial # 149  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 602  Trial # 150  Group1-stimuli/group1-block2/fake-group2-b2/en...
#
#     ground_truth                   image_name   result   result   result  \
# 3           real          Group1_IMG_0022.jpg  correct  correct  correct
# 4           fake  encoded_Group2_IMG_0386.jpg  correct  correct  correct
# 5           real          Group1_IMG_9704.jpg    wrong  correct    wrong
# 6           real          Group1_IMG_0406.jpg  correct  correct  correct
# 7           fake  encoded_Group2_IMG_0364.jpg  correct  correct  correct
# ..           ...                          ...      ...      ...      ...
# 598         fake  encoded_Group2_IMG_9935.jpg  correct    wrong  correct
# 599         real          Group1_IMG_9897.jpg  correct  correct  correct
# 600         real          Group1_IMG_0453.jpg  correct  correct  correct
# 601         fake  encoded_Group2_IMG_0308.jpg  correct  correct  correct
# 602         fake  encoded_Group2_IMG_0249.jpg  correct    wrong  correct
#
#       result   result   result   result   result   result   result   result
# 3    correct  correct    wrong  correct    wrong  correct    wrong  correct
# 4      wrong  correct    wrong  correct    wrong  correct    wrong  correct
# 5      wrong  correct  correct    wrong    wrong    wrong    wrong  correct
# 6      wrong  correct  correct  correct  correct  correct  correct  correct
# 7    correct  correct  correct  correct  correct  correct  correct    wrong
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 598    wrong    wrong    wrong    wrong  correct    wrong    wrong  correct
# 599  correct    wrong  correct  correct  correct  correct  correct  correct
# 600    wrong  correct  correct  correct  correct  correct  correct  correct
# 601  correct  correct  correct  correct  correct  correct  correct  correct
# 602    wrong  correct    wrong  correct  correct    wrong  correct    wrong
#
# [600 rows x 15 columns]
# Repetition 1:
# 300
# [[108  42]
#  [ 37 113]]
# Error rate for real images: 0.28
# Error rate for fake images: 0.24666666666666667
# Repetition 2:
# 300
# [[111  39]
#  [ 23 127]]
# Error rate for real images: 0.26
# Error rate for fake images: 0.15333333333333332
# Overall:
# 600
# [[219  81]
#  [ 60 240]]
# Error rate for real images: 0.27
# Error rate for fake images: 0.2
# Wrong in both: 30
# Number of encoded image been misjudged in both repetition: 0.06
# Number of real image been misjudged in both repetition: 0.14
#        Trial_num                                         image_path  \
# 3      Trial # 1  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 4      Trial # 2  Group1-stimuli/group1-block1/fake-group2-b1/en...
# 5      Trial # 3  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 6      Trial # 4  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 7      Trial # 5  Group1-stimuli/group1-block1/fake-group2-b1/en...
# ..           ...                                                ...
# 598  Trial # 146  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 599  Trial # 147  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 600  Trial # 148  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 601  Trial # 149  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 602  Trial # 150  Group1-stimuli/group1-block2/fake-group2-b2/en...
#
#     ground_truth                   image_name   result   result   result  \
# 3           real          Group1_IMG_0022.jpg  correct  correct  correct
# 4           fake  encoded_Group2_IMG_0386.jpg  correct  correct  correct
# 5           real          Group1_IMG_9704.jpg    wrong  correct    wrong
# 6           real          Group1_IMG_0406.jpg  correct  correct  correct
# 7           fake  encoded_Group2_IMG_0364.jpg  correct  correct  correct
# ..           ...                          ...      ...      ...      ...
# 598         fake  encoded_Group2_IMG_9935.jpg  correct    wrong  correct
# 599         real          Group1_IMG_9897.jpg  correct  correct  correct
# 600         real          Group1_IMG_0453.jpg  correct  correct  correct
# 601         fake  encoded_Group2_IMG_0308.jpg  correct  correct  correct
# 602         fake  encoded_Group2_IMG_0249.jpg  correct    wrong  correct
#
#       result   result   result   result   result   result   result   result  \
# 3    correct  correct    wrong  correct    wrong  correct    wrong  correct
# 4      wrong  correct    wrong  correct    wrong  correct    wrong  correct
# 5      wrong  correct  correct    wrong    wrong    wrong    wrong  correct
# 6      wrong  correct  correct  correct  correct  correct  correct  correct
# 7    correct  correct  correct  correct  correct  correct  correct    wrong
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 598    wrong    wrong    wrong    wrong  correct    wrong    wrong  correct
# 599  correct    wrong  correct  correct  correct  correct  correct  correct
# 600    wrong  correct  correct  correct  correct  correct  correct  correct
# 601  correct  correct  correct  correct  correct  correct  correct  correct
# 602    wrong  correct    wrong  correct  correct    wrong  correct    wrong
#
#       result
# 3    correct
# 4      wrong
# 5      wrong
# 6    correct
# 7    correct
# ..       ...
# 598    wrong
# 599  correct
# 600  correct
# 601  correct
# 602  correct
#
# [600 rows x 16 columns]
# Repetition 1:
# 300
# [[133  17]
#  [ 35 115]]
# Error rate for real images: 0.11333333333333333
# Error rate for fake images: 0.23333333333333334
# Repetition 2:
# 300
# [[134  16]
#  [ 38 112]]
# Error rate for real images: 0.10666666666666667
# Error rate for fake images: 0.25333333333333335
# Overall:
# 600
# [[267  33]
#  [ 73 227]]
# Error rate for real images: 0.11
# Error rate for fake images: 0.24333333333333335
# Wrong in both: 24
# Number of encoded image been misjudged in both repetition: 0.10666666666666667
# Number of real image been misjudged in both repetition: 0.05333333333333334
#        Trial_num                                         image_path  \
# 3      Trial # 1  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 4      Trial # 2  Group1-stimuli/group1-block1/fake-group2-b1/en...
# 5      Trial # 3  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 6      Trial # 4  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 7      Trial # 5  Group1-stimuli/group1-block1/fake-group2-b1/en...
# ..           ...                                                ...
# 598  Trial # 146  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 599  Trial # 147  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 600  Trial # 148  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 601  Trial # 149  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 602  Trial # 150  Group1-stimuli/group1-block2/fake-group2-b2/en...
#
#     ground_truth                   image_name   result   result   result  \
# 3           real          Group1_IMG_0022.jpg  correct  correct  correct
# 4           fake  encoded_Group2_IMG_0386.jpg  correct  correct  correct
# 5           real          Group1_IMG_9704.jpg    wrong  correct    wrong
# 6           real          Group1_IMG_0406.jpg  correct  correct  correct
# 7           fake  encoded_Group2_IMG_0364.jpg  correct  correct  correct
# ..           ...                          ...      ...      ...      ...
# 598         fake  encoded_Group2_IMG_9935.jpg  correct    wrong  correct
# 599         real          Group1_IMG_9897.jpg  correct  correct  correct
# 600         real          Group1_IMG_0453.jpg  correct  correct  correct
# 601         fake  encoded_Group2_IMG_0308.jpg  correct  correct  correct
# 602         fake  encoded_Group2_IMG_0249.jpg  correct    wrong  correct
#
#       result   result   result   result   result   result   result   result  \
# 3    correct  correct    wrong  correct    wrong  correct    wrong  correct
# 4      wrong  correct    wrong  correct    wrong  correct    wrong  correct
# 5      wrong  correct  correct    wrong    wrong    wrong    wrong  correct
# 6      wrong  correct  correct  correct  correct  correct  correct  correct
# 7    correct  correct  correct  correct  correct  correct  correct    wrong
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 598    wrong    wrong    wrong    wrong  correct    wrong    wrong  correct
# 599  correct    wrong  correct  correct  correct  correct  correct  correct
# 600    wrong  correct  correct  correct  correct  correct  correct  correct
# 601  correct  correct  correct  correct  correct  correct  correct  correct
# 602    wrong  correct    wrong  correct  correct    wrong  correct    wrong
#
#       result   result
# 3    correct  correct
# 4      wrong  correct
# 5      wrong    wrong
# 6    correct  correct
# 7    correct  correct
# ..       ...      ...
# 598    wrong  correct
# 599  correct  correct
# 600  correct  correct
# 601  correct  correct
# 602  correct  correct
#
# [600 rows x 17 columns]
# Repetition 1:
# 300
# [[ 90  60]
#  [ 27 123]]
# Error rate for real images: 0.4
# Error rate for fake images: 0.18
# Repetition 2:
# 300
# [[ 72  78]
#  [ 26 124]]
# Error rate for real images: 0.52
# Error rate for fake images: 0.17333333333333334
# Overall:
# 600
# [[162 138]
#  [ 53 247]]
# Error rate for real images: 0.46
# Error rate for fake images: 0.17666666666666667
# Wrong in both: 52
# Number of encoded image been misjudged in both repetition: 0.07333333333333333
# Number of real image been misjudged in both repetition: 0.2733333333333333
#        Trial_num                                         image_path  \
# 3      Trial # 1  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 4      Trial # 2  Group1-stimuli/group1-block1/fake-group2-b1/en...
# 5      Trial # 3  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 6      Trial # 4  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 7      Trial # 5  Group1-stimuli/group1-block1/fake-group2-b1/en...
# ..           ...                                                ...
# 598  Trial # 146  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 599  Trial # 147  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 600  Trial # 148  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 601  Trial # 149  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 602  Trial # 150  Group1-stimuli/group1-block2/fake-group2-b2/en...
#
#     ground_truth                   image_name   result   result   result  \
# 3           real          Group1_IMG_0022.jpg  correct  correct  correct
# 4           fake  encoded_Group2_IMG_0386.jpg  correct  correct  correct
# 5           real          Group1_IMG_9704.jpg    wrong  correct    wrong
# 6           real          Group1_IMG_0406.jpg  correct  correct  correct
# 7           fake  encoded_Group2_IMG_0364.jpg  correct  correct  correct
# ..           ...                          ...      ...      ...      ...
# 598         fake  encoded_Group2_IMG_9935.jpg  correct    wrong  correct
# 599         real          Group1_IMG_9897.jpg  correct  correct  correct
# 600         real          Group1_IMG_0453.jpg  correct  correct  correct
# 601         fake  encoded_Group2_IMG_0308.jpg  correct  correct  correct
# 602         fake  encoded_Group2_IMG_0249.jpg  correct    wrong  correct
#
#       result   result   result   result   result   result   result   result  \
# 3    correct  correct    wrong  correct    wrong  correct    wrong  correct
# 4      wrong  correct    wrong  correct    wrong  correct    wrong  correct
# 5      wrong  correct  correct    wrong    wrong    wrong    wrong  correct
# 6      wrong  correct  correct  correct  correct  correct  correct  correct
# 7    correct  correct  correct  correct  correct  correct  correct    wrong
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 598    wrong    wrong    wrong    wrong  correct    wrong    wrong  correct
# 599  correct    wrong  correct  correct  correct  correct  correct  correct
# 600    wrong  correct  correct  correct  correct  correct  correct  correct
# 601  correct  correct  correct  correct  correct  correct  correct  correct
# 602    wrong  correct    wrong  correct  correct    wrong  correct    wrong
#
#       result   result   result
# 3    correct  correct  correct
# 4      wrong  correct  correct
# 5      wrong    wrong  correct
# 6    correct  correct  correct
# 7    correct  correct  correct
# ..       ...      ...      ...
# 598    wrong  correct    wrong
# 599  correct  correct  correct
# 600  correct  correct    wrong
# 601  correct  correct  correct
# 602  correct  correct    wrong
#
# [600 rows x 18 columns]
# Repetition 1:
# 300
# [[121  29]
#  [ 29 121]]
# Error rate for real images: 0.19333333333333333
# Error rate for fake images: 0.19333333333333333
# Repetition 2:
# 300
# [[143   7]
#  [ 26 124]]
# Error rate for real images: 0.04666666666666667
# Error rate for fake images: 0.17333333333333334
# Overall:
# 600
# [[264  36]
#  [ 55 245]]
# Error rate for real images: 0.12
# Error rate for fake images: 0.18333333333333332
# Wrong in both: 9
# Number of encoded image been misjudged in both repetition: 0.04
# Number of real image been misjudged in both repetition: 0.02
#        Trial_num                                         image_path  \
# 3      Trial # 1  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 4      Trial # 2  Group1-stimuli/group1-block1/fake-group2-b1/en...
# 5      Trial # 3  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 6      Trial # 4  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 7      Trial # 5  Group1-stimuli/group1-block1/fake-group2-b1/en...
# ..           ...                                                ...
# 598  Trial # 146  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 599  Trial # 147  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 600  Trial # 148  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 601  Trial # 149  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 602  Trial # 150  Group1-stimuli/group1-block2/fake-group2-b2/en...
#
#     ground_truth                   image_name   result   result   result  \
# 3           real          Group1_IMG_0022.jpg  correct  correct  correct
# 4           fake  encoded_Group2_IMG_0386.jpg  correct  correct  correct
# 5           real          Group1_IMG_9704.jpg    wrong  correct    wrong
# 6           real          Group1_IMG_0406.jpg  correct  correct  correct
# 7           fake  encoded_Group2_IMG_0364.jpg  correct  correct  correct
# ..           ...                          ...      ...      ...      ...
# 598         fake  encoded_Group2_IMG_9935.jpg  correct    wrong  correct
# 599         real          Group1_IMG_9897.jpg  correct  correct  correct
# 600         real          Group1_IMG_0453.jpg  correct  correct  correct
# 601         fake  encoded_Group2_IMG_0308.jpg  correct  correct  correct
# 602         fake  encoded_Group2_IMG_0249.jpg  correct    wrong  correct
#
#       result   result   result   result   result   result   result   result  \
# 3    correct  correct    wrong  correct    wrong  correct    wrong  correct
# 4      wrong  correct    wrong  correct    wrong  correct    wrong  correct
# 5      wrong  correct  correct    wrong    wrong    wrong    wrong  correct
# 6      wrong  correct  correct  correct  correct  correct  correct  correct
# 7    correct  correct  correct  correct  correct  correct  correct    wrong
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 598    wrong    wrong    wrong    wrong  correct    wrong    wrong  correct
# 599  correct    wrong  correct  correct  correct  correct  correct  correct
# 600    wrong  correct  correct  correct  correct  correct  correct  correct
# 601  correct  correct  correct  correct  correct  correct  correct  correct
# 602    wrong  correct    wrong  correct  correct    wrong  correct    wrong
#
#       result   result   result   result
# 3    correct  correct  correct  correct
# 4      wrong  correct  correct  correct
# 5      wrong    wrong  correct  correct
# 6    correct  correct  correct  correct
# 7    correct  correct  correct  correct
# ..       ...      ...      ...      ...
# 598    wrong  correct    wrong    wrong
# 599  correct  correct  correct  correct
# 600  correct  correct    wrong  correct
# 601  correct  correct  correct  correct
# 602  correct  correct    wrong  correct
#
# [600 rows x 19 columns]
# Repetition 1:
# 300
# [[72 78]
#  [63 87]]
# Error rate for real images: 0.52
# Error rate for fake images: 0.42
# Repetition 2:
# 300
# [[77 73]
#  [67 83]]
# Error rate for real images: 0.4866666666666667
# Error rate for fake images: 0.44666666666666666
# Overall:
# 600
# [[149 151]
#  [130 170]]
# Error rate for real images: 0.5033333333333333
# Error rate for fake images: 0.43333333333333335
# Wrong in both: 115
# Number of encoded image been misjudged in both repetition: 0.32
# Number of real image been misjudged in both repetition: 0.44666666666666666
#        Trial_num                                         image_path  \
# 3      Trial # 1  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 4      Trial # 2  Group1-stimuli/group1-block1/fake-group2-b1/en...
# 5      Trial # 3  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 6      Trial # 4  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 7      Trial # 5  Group1-stimuli/group1-block1/fake-group2-b1/en...
# ..           ...                                                ...
# 598  Trial # 146  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 599  Trial # 147  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 600  Trial # 148  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 601  Trial # 149  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 602  Trial # 150  Group1-stimuli/group1-block2/fake-group2-b2/en...
#
#     ground_truth                   image_name   result   result   result  \
# 3           real          Group1_IMG_0022.jpg  correct  correct  correct
# 4           fake  encoded_Group2_IMG_0386.jpg  correct  correct  correct
# 5           real          Group1_IMG_9704.jpg    wrong  correct    wrong
# 6           real          Group1_IMG_0406.jpg  correct  correct  correct
# 7           fake  encoded_Group2_IMG_0364.jpg  correct  correct  correct
# ..           ...                          ...      ...      ...      ...
# 598         fake  encoded_Group2_IMG_9935.jpg  correct    wrong  correct
# 599         real          Group1_IMG_9897.jpg  correct  correct  correct
# 600         real          Group1_IMG_0453.jpg  correct  correct  correct
# 601         fake  encoded_Group2_IMG_0308.jpg  correct  correct  correct
# 602         fake  encoded_Group2_IMG_0249.jpg  correct    wrong  correct
#
#       result   result   result   result   result   result   result   result  \
# 3    correct  correct    wrong  correct    wrong  correct    wrong  correct
# 4      wrong  correct    wrong  correct    wrong  correct    wrong  correct
# 5      wrong  correct  correct    wrong    wrong    wrong    wrong  correct
# 6      wrong  correct  correct  correct  correct  correct  correct  correct
# 7    correct  correct  correct  correct  correct  correct  correct    wrong
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 598    wrong    wrong    wrong    wrong  correct    wrong    wrong  correct
# 599  correct    wrong  correct  correct  correct  correct  correct  correct
# 600    wrong  correct  correct  correct  correct  correct  correct  correct
# 601  correct  correct  correct  correct  correct  correct  correct  correct
# 602    wrong  correct    wrong  correct  correct    wrong  correct    wrong
#
#       result   result   result   result   result
# 3    correct  correct  correct  correct    wrong
# 4      wrong  correct  correct  correct  correct
# 5      wrong    wrong  correct  correct    wrong
# 6    correct  correct  correct  correct    wrong
# 7    correct  correct  correct  correct  correct
# ..       ...      ...      ...      ...      ...
# 598    wrong  correct    wrong    wrong  correct
# 599  correct  correct  correct  correct    wrong
# 600  correct  correct    wrong  correct  correct
# 601  correct  correct  correct  correct    wrong
# 602  correct  correct    wrong  correct    wrong
#
# [600 rows x 20 columns]
# Repetition 1:
# 300
# [[94 56]
#  [75 75]]
# Error rate for real images: 0.37333333333333335
# Error rate for fake images: 0.5
# Repetition 2:
# 300
# [[113  37]
#  [ 83  67]]
# Error rate for real images: 0.24666666666666667
# Error rate for fake images: 0.5533333333333333
# Overall:
# 600
# [[207  93]
#  [158 142]]
# Error rate for real images: 0.31
# Error rate for fake images: 0.5266666666666666
# Wrong in both: 71
# Number of encoded image been misjudged in both repetition: 0.3333333333333333
# Number of real image been misjudged in both repetition: 0.14
#        Trial_num                                         image_path  \
# 3      Trial # 1  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 4      Trial # 2  Group1-stimuli/group1-block1/fake-group2-b1/en...
# 5      Trial # 3  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 6      Trial # 4  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 7      Trial # 5  Group1-stimuli/group1-block1/fake-group2-b1/en...
# ..           ...                                                ...
# 598  Trial # 146  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 599  Trial # 147  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 600  Trial # 148  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 601  Trial # 149  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 602  Trial # 150  Group1-stimuli/group1-block2/fake-group2-b2/en...
#
#     ground_truth                   image_name   result   result   result  \
# 3           real          Group1_IMG_0022.jpg  correct  correct  correct
# 4           fake  encoded_Group2_IMG_0386.jpg  correct  correct  correct
# 5           real          Group1_IMG_9704.jpg    wrong  correct    wrong
# 6           real          Group1_IMG_0406.jpg  correct  correct  correct
# 7           fake  encoded_Group2_IMG_0364.jpg  correct  correct  correct
# ..           ...                          ...      ...      ...      ...
# 598         fake  encoded_Group2_IMG_9935.jpg  correct    wrong  correct
# 599         real          Group1_IMG_9897.jpg  correct  correct  correct
# 600         real          Group1_IMG_0453.jpg  correct  correct  correct
# 601         fake  encoded_Group2_IMG_0308.jpg  correct  correct  correct
# 602         fake  encoded_Group2_IMG_0249.jpg  correct    wrong  correct
#
#       result   result   result  ...   result   result   result   result  \
# 3    correct  correct    wrong  ...    wrong  correct    wrong  correct
# 4      wrong  correct    wrong  ...    wrong  correct    wrong  correct
# 5      wrong  correct  correct  ...    wrong    wrong    wrong  correct
# 6      wrong  correct  correct  ...  correct  correct  correct  correct
# 7    correct  correct  correct  ...  correct  correct  correct    wrong
# ..       ...      ...      ...  ...      ...      ...      ...      ...
# 598    wrong    wrong    wrong  ...  correct    wrong    wrong  correct
# 599  correct    wrong  correct  ...  correct  correct  correct  correct
# 600    wrong  correct  correct  ...  correct  correct  correct  correct
# 601  correct  correct  correct  ...  correct  correct  correct  correct
# 602    wrong  correct    wrong  ...  correct    wrong  correct    wrong
#
#       result   result   result   result   result   result
# 3    correct  correct  correct  correct    wrong  correct
# 4      wrong  correct  correct  correct  correct    wrong
# 5      wrong    wrong  correct  correct    wrong  correct
# 6    correct  correct  correct  correct    wrong  correct
# 7    correct  correct  correct  correct  correct  correct
# ..       ...      ...      ...      ...      ...      ...
# 598    wrong  correct    wrong    wrong  correct    wrong
# 599  correct  correct  correct  correct    wrong  correct
# 600  correct  correct    wrong  correct  correct  correct
# 601  correct  correct  correct  correct    wrong    wrong
# 602  correct  correct    wrong  correct    wrong    wrong
#
# [600 rows x 21 columns]
# Repetition 1:
# 300
# [[100  50]
#  [ 42 108]]
# Error rate for real images: 0.3333333333333333
# Error rate for fake images: 0.28
# Repetition 2:
# 300
# [[108  42]
#  [ 19 131]]
# Error rate for real images: 0.28
# Error rate for fake images: 0.12666666666666668
# Overall:
# 600
# [[208  92]
#  [ 61 239]]
# Error rate for real images: 0.30666666666666664
# Error rate for fake images: 0.20333333333333334
# Wrong in both: 25
# Number of encoded image been misjudged in both repetition: 0.06
# Number of real image been misjudged in both repetition: 0.10666666666666667
#        Trial_num                                         image_path  \
# 3      Trial # 1  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 4      Trial # 2  Group1-stimuli/group1-block1/fake-group2-b1/en...
# 5      Trial # 3  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 6      Trial # 4  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 7      Trial # 5  Group1-stimuli/group1-block1/fake-group2-b1/en...
# ..           ...                                                ...
# 598  Trial # 146  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 599  Trial # 147  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 600  Trial # 148  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 601  Trial # 149  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 602  Trial # 150  Group1-stimuli/group1-block2/fake-group2-b2/en...
#
#     ground_truth                   image_name   result   result   result  \
# 3           real          Group1_IMG_0022.jpg  correct  correct  correct
# 4           fake  encoded_Group2_IMG_0386.jpg  correct  correct  correct
# 5           real          Group1_IMG_9704.jpg    wrong  correct    wrong
# 6           real          Group1_IMG_0406.jpg  correct  correct  correct
# 7           fake  encoded_Group2_IMG_0364.jpg  correct  correct  correct
# ..           ...                          ...      ...      ...      ...
# 598         fake  encoded_Group2_IMG_9935.jpg  correct    wrong  correct
# 599         real          Group1_IMG_9897.jpg  correct  correct  correct
# 600         real          Group1_IMG_0453.jpg  correct  correct  correct
# 601         fake  encoded_Group2_IMG_0308.jpg  correct  correct  correct
# 602         fake  encoded_Group2_IMG_0249.jpg  correct    wrong  correct
#
#       result   result   result  ...   result   result   result   result  \
# 3    correct  correct    wrong  ...  correct    wrong  correct  correct
# 4      wrong  correct    wrong  ...  correct    wrong  correct    wrong
# 5      wrong  correct  correct  ...    wrong    wrong  correct    wrong
# 6      wrong  correct  correct  ...  correct  correct  correct  correct
# 7    correct  correct  correct  ...  correct  correct    wrong  correct
# ..       ...      ...      ...  ...      ...      ...      ...      ...
# 598    wrong    wrong    wrong  ...    wrong    wrong  correct    wrong
# 599  correct    wrong  correct  ...  correct  correct  correct  correct
# 600    wrong  correct  correct  ...  correct  correct  correct  correct
# 601  correct  correct  correct  ...  correct  correct  correct  correct
# 602    wrong  correct    wrong  ...    wrong  correct    wrong  correct
#
#       result   result   result   result   result   result
# 3    correct  correct  correct    wrong  correct  correct
# 4    correct  correct  correct  correct    wrong  correct
# 5      wrong  correct  correct    wrong  correct  correct
# 6    correct  correct  correct    wrong  correct  correct
# 7    correct  correct  correct  correct  correct  correct
# ..       ...      ...      ...      ...      ...      ...
# 598  correct    wrong    wrong  correct    wrong  correct
# 599  correct  correct  correct    wrong  correct  correct
# 600  correct    wrong  correct  correct  correct    wrong
# 601  correct  correct  correct    wrong    wrong  correct
# 602  correct    wrong  correct    wrong    wrong    wrong
#
# [600 rows x 22 columns]
# Repetition 1:
# 300
# [[129  21]
#  [ 15 135]]
# Error rate for real images: 0.14
# Error rate for fake images: 0.1
# Repetition 2:
# 300
# [[124  26]
#  [  3 147]]
# Error rate for real images: 0.17333333333333334
# Error rate for fake images: 0.02
# Overall:
# 600
# [[253  47]
#  [ 18 282]]
# Error rate for real images: 0.15666666666666668
# Error rate for fake images: 0.06
# Wrong in both: 14
# Number of encoded image been misjudged in both repetition: 0.006666666666666667
# Number of real image been misjudged in both repetition: 0.08666666666666667
#        Trial_num                                         image_path  \
# 3      Trial # 1  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 4      Trial # 2  Group1-stimuli/group1-block1/fake-group2-b1/en...
# 5      Trial # 3  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 6      Trial # 4  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 7      Trial # 5  Group1-stimuli/group1-block1/fake-group2-b1/en...
# ..           ...                                                ...
# 598  Trial # 146  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 599  Trial # 147  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 600  Trial # 148  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 601  Trial # 149  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 602  Trial # 150  Group1-stimuli/group1-block2/fake-group2-b2/en...
#
#     ground_truth                   image_name   result   result   result  \
# 3           real          Group1_IMG_0022.jpg  correct  correct  correct
# 4           fake  encoded_Group2_IMG_0386.jpg  correct  correct  correct
# 5           real          Group1_IMG_9704.jpg    wrong  correct    wrong
# 6           real          Group1_IMG_0406.jpg  correct  correct  correct
# 7           fake  encoded_Group2_IMG_0364.jpg  correct  correct  correct
# ..           ...                          ...      ...      ...      ...
# 598         fake  encoded_Group2_IMG_9935.jpg  correct    wrong  correct
# 599         real          Group1_IMG_9897.jpg  correct  correct  correct
# 600         real          Group1_IMG_0453.jpg  correct  correct  correct
# 601         fake  encoded_Group2_IMG_0308.jpg  correct  correct  correct
# 602         fake  encoded_Group2_IMG_0249.jpg  correct    wrong  correct
#
#       result   result   result  ...   result   result   result   result  \
# 3    correct  correct    wrong  ...    wrong  correct  correct  correct
# 4      wrong  correct    wrong  ...    wrong  correct    wrong  correct
# 5      wrong  correct  correct  ...    wrong  correct    wrong    wrong
# 6      wrong  correct  correct  ...  correct  correct  correct  correct
# 7    correct  correct  correct  ...  correct    wrong  correct  correct
# ..       ...      ...      ...  ...      ...      ...      ...      ...
# 598    wrong    wrong    wrong  ...    wrong  correct    wrong  correct
# 599  correct    wrong  correct  ...  correct  correct  correct  correct
# 600    wrong  correct  correct  ...  correct  correct  correct  correct
# 601  correct  correct  correct  ...  correct  correct  correct  correct
# 602    wrong  correct    wrong  ...  correct    wrong  correct  correct
#
#       result   result   result   result   result   result
# 3    correct  correct    wrong  correct  correct  correct
# 4    correct  correct  correct    wrong  correct    wrong
# 5    correct  correct    wrong  correct  correct  correct
# 6    correct  correct    wrong  correct  correct  correct
# 7    correct  correct  correct  correct  correct  correct
# ..       ...      ...      ...      ...      ...      ...
# 598    wrong    wrong  correct    wrong  correct  correct
# 599  correct  correct    wrong  correct  correct  correct
# 600    wrong  correct  correct  correct    wrong  correct
# 601  correct  correct    wrong    wrong  correct  correct
# 602    wrong  correct    wrong    wrong    wrong  correct
#
# [600 rows x 23 columns]
# Repetition 1:
# 300
# [[117  33]
#  [ 46 104]]
# Error rate for real images: 0.22
# Error rate for fake images: 0.30666666666666664
# Repetition 2:
# 300
# [[129  21]
#  [ 43 107]]
# Error rate for real images: 0.14
# Error rate for fake images: 0.2866666666666667
# Overall:
# 600
# [[246  54]
#  [ 89 211]]
# Error rate for real images: 0.18
# Error rate for fake images: 0.2966666666666667
# Wrong in both: 28
# Number of encoded image been misjudged in both repetition: 0.1
# Number of real image been misjudged in both repetition: 0.08666666666666667
#        Trial_num                                         image_path  \
# 3      Trial # 1  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 4      Trial # 2  Group1-stimuli/group1-block1/fake-group2-b1/en...
# 5      Trial # 3  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 6      Trial # 4  Group1-stimuli/group1-block1/real-group1-b1/Gr...
# 7      Trial # 5  Group1-stimuli/group1-block1/fake-group2-b1/en...
# ..           ...                                                ...
# 598  Trial # 146  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 599  Trial # 147  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 600  Trial # 148  Group1-stimuli/group1-block2/real-group1-b2/Gr...
# 601  Trial # 149  Group1-stimuli/group1-block2/fake-group2-b2/en...
# 602  Trial # 150  Group1-stimuli/group1-block2/fake-group2-b2/en...
#
#     ground_truth                   image_name   result   result   result  \
# 3           real          Group1_IMG_0022.jpg  correct  correct  correct
# 4           fake  encoded_Group2_IMG_0386.jpg  correct  correct  correct
# 5           real          Group1_IMG_9704.jpg    wrong  correct    wrong
# 6           real          Group1_IMG_0406.jpg  correct  correct  correct
# 7           fake  encoded_Group2_IMG_0364.jpg  correct  correct  correct
# ..           ...                          ...      ...      ...      ...
# 598         fake  encoded_Group2_IMG_9935.jpg  correct    wrong  correct
# 599         real          Group1_IMG_9897.jpg  correct  correct  correct
# 600         real          Group1_IMG_0453.jpg  correct  correct  correct
# 601         fake  encoded_Group2_IMG_0308.jpg  correct  correct  correct
# 602         fake  encoded_Group2_IMG_0249.jpg  correct    wrong  correct
#
#       result   result   result  ...   result   result   result   result  \
# 3    correct  correct    wrong  ...  correct  correct  correct  correct
# 4      wrong  correct    wrong  ...  correct    wrong  correct  correct
# 5      wrong  correct  correct  ...  correct    wrong    wrong  correct
# 6      wrong  correct  correct  ...  correct  correct  correct  correct
# 7    correct  correct  correct  ...    wrong  correct  correct  correct
# ..       ...      ...      ...  ...      ...      ...      ...      ...
# 598    wrong    wrong    wrong  ...  correct    wrong  correct    wrong
# 599  correct    wrong  correct  ...  correct  correct  correct  correct
# 600    wrong  correct  correct  ...  correct  correct  correct    wrong
# 601  correct  correct  correct  ...  correct  correct  correct  correct
# 602    wrong  correct    wrong  ...    wrong  correct  correct    wrong
#
#       result   result   result   result   result   result
# 3    correct    wrong  correct  correct  correct    wrong
# 4    correct  correct    wrong  correct    wrong    wrong
# 5    correct    wrong  correct  correct  correct    wrong
# 6    correct    wrong  correct  correct  correct  correct
# 7    correct  correct  correct  correct  correct  correct
# ..       ...      ...      ...      ...      ...      ...
# 598    wrong  correct    wrong  correct  correct  correct
# 599  correct    wrong  correct  correct  correct  correct
# 600  correct  correct  correct    wrong  correct  correct
# 601  correct    wrong    wrong  correct  correct  correct
# 602  correct    wrong    wrong    wrong  correct  correct
#
# [600 rows x 24 columns]

# %% [markdown]
# # Plot Error rate for each observer

# %%
sns.set_context(context='poster', font_scale=0.5)

data_for_boxplot = [all_people_real_fake['real_err_rate_all'], all_people_real_fake['fake_err_rate_all']]
fig1, ax1 = plt.subplots()
labels = ["Error rate for judging \n Real images", "Error rate for judging \n Generated images"]


ax1 = sns.swarmplot(data=data_for_boxplot,  palette=["#bdbdbd", "#2ca02c"], size = 8)

sns.despine()

ax1.set_title("Distribution of Observers' Error Rate")
ax1.set_xticklabels(labels)
ax1.set_ylabel("Observer's Error rate")
plt.show()

# %%
##Define color map

real_fake_color_palette = dict(real="#bdbdbd", fake="#2ca02c")


real_fake_hue_order = ["real","fake"]

# %%
## Add percent wrong column

aggregate_result["percent_wrong"] = aggregate_result["num_wrong"] / (aggregate_result["num_wrong"] + aggregate_result["num_correct"])

aggregate_result["percent_correct"] = 1 - aggregate_result["percent_wrong"]

rep = 300 * ["Rep 1"] + 300 * ["Rep 2"]

aggregate_result["Repeat"] = rep

# %%
## Splits 2 repeats. Match the 2nd repeat to first
rep1 = aggregate_result.iloc[0:300]
rep2 = aggregate_result.iloc[300:]

rep2 = rep2.set_index('image_name')
rep2 = rep2.reindex(index=rep1['image_name'])
rep2 = rep2.reset_index()

# %% [markdown]
# # Show aggregated error for fake and real judgement (Figure 2C)

# %%
aggregate_result.groupby("ground_truth").sum()/6000
# Out:
#               num_correct  num_wrong  percent_wrong  percent_correct
# ground_truth
# fake             0.718333   0.281667       0.014083         0.035917
# real             0.742167   0.257833       0.012892         0.037108

# %%
rep1.groupby("ground_truth").sum()/3000
# Out:
#               num_correct  num_wrong  percent_wrong  percent_correct
# ground_truth
# fake             0.721333   0.278667       0.013933         0.036067
# real             0.724333   0.275667       0.013783         0.036217

# %%
rep2.groupby("ground_truth").sum()/3000
# Out:
#               num_correct  num_wrong  percent_wrong  percent_correct
# ground_truth
# fake             0.715333   0.284667       0.014233         0.035767
# real             0.760000   0.240000       0.012000         0.038000

# %% [markdown]
# # Plot distribution of error (Figure 2D)

# %%
real_fake_hue_order = ["fake", "real"]

real_fake_color_palette = dict(real="#bdbdbd", fake="#2ca02c")


plot_error_image = sns.displot(aggregate_result, x="percent_wrong", hue="ground_truth", col="Repeat", stat="percent", alpha=0.7,
                               binwidth=0.1, common_norm=False, fill=True, edgecolor= "white",linewidth=1,
                               hue_order=real_fake_hue_order,palette=real_fake_color_palette, legend = True)
sns.despine(offset=10, left=False, right = True)
plot_error_image.set(xticks=np.arange(0,1,0.1), yticks=np.arange(0,50,10))
#plot_error_image.set(xlabel=None, ylabel=None, xticklabels=[], yticklabels=[])
plot_error_image.set(xlabel='Percentage of observers misjudging judged an image', ylabel='Percentage of images')
